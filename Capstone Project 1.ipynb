# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Data Collection

# %%
ds = pd.read_csv('C:\\Users\\Admin\\excel\\hotstar.csv')

# %%
ds.head(10)
# Out:
#    hotstar_id                                title  \
# 0  1000087439                Sambha - Aajcha Chawa
# 1  1260023113  Cars Toon: Mater And The Ghostlight
# 2  1260103188                Kanmani Rambo Khatija
# 3  1260126754                            Butterfly
# 4  1260018228                           Sister Act
# 5  1000218684                              Traffic
# 6  1000110774                    Kinnaripuzhayoram
# 7  1000066604                                Meher
# 8  1000187193                                 Remo
# 9  1610011340                                Tanga
#
#                                          description      genre  year  \
# 0  A young man sets off on a mission to clean up ...     Action  2012
# 1  Mater is haunted by a mysterious blue light th...  Animation  2006
# 2  Unlucky since birth, Rambo finds hope when he ...    Romance  2022
# 3  While trying to rescue her sister's kids from ...   Thriller  2022
# ...

# %%
ds.tail(10)
# Out:
#       hotstar_id                               title  \
# 6864       18326                           Lalit 205
# 6865  1260117610  Suvarna Dasara Utsava Naari Namana
# 6866        5287    Zindagi Abhi Baki Hai Mere Ghost
# 6867        9693                              Vihari
# 6868  1260000390                      Aranmanai Kili
# 6869  1260127438                          Will Trent
# 6870  1260008508            KBD Juniors - Qualifiers
# 6871       12551                  Dil Hai Hindustani
# 6872  1260065225                        On The Brink
# 6873  1260129361                           Mahanadhi
#
#                                             description             genre  \
# 6864  Meet the Rajadhyakshas of Lalit 205. In the er...             Drama
# 6865  Celebrate the occasion of Vijayadashmi with th...           Reality
# 6866  Yug, an orphan, lands in a mansion owned by a ...            Family
# 6867  Vihari is a Telugu reality show on Maa TV. It ...            Travel
# ...

# %% [markdown]
# Dataset Introduction

# %% [raw]
# Disney+ Hotstar is a popular streaming platform that offers a mix of movies, TV shows, live sports, and exclusive content. It is owned by Disney and was previously known as Disney+Hotstar. The platform provides content from Bollywood, Hollywood, regional cinema, and Disney+ Originals, along with Hotstar Specials.
#
# It was originally launched as Hotstar, debuted on February 11, 2015. It was developed by Star India and quickly became India's leading streaming service. Following Disney's acquisition of 21st Century Fox in 2019, Hotstar was integrated into Disney+ and rebranded as Disney+ Hotstar in April 2020.
# Recently, in February 2025, Disney+ Hotstar merged with JioCinema to form JioHotstar, offering a combined streaming experience
# The co-branded service added Disney+ original programming, and films and television series from its main content brands of Walt Disney Studios, Pixar, Marvel Studios, Lucasfilm, and National Geographic alongside the domestic and third-party content already carried on the platform.
#
# Users can watch live sports, including cricket, football, tennis, and Formula 1. The streaming quality goes up to 4K Ultra HD for selected content. Disney+ Hotstar supports multiple devices, including mobile phones, web browsers, smart TVs, and connected TVs.
# The subscription plans include Mobile (₹149 for 3 months, ₹499 per year), Super (₹299 for 3 months, ₹899 per year), and Premium (₹299 per month, ₹1499 per year). The Premium plan offers an ad-free experience except for live sports and events.

# %% [raw]
# The dataset talks about:
#
# -hotstar_id: ID of tv show and movie.
# -title: Title of tv show and movie.
# -description: Short Description describing content.
# -genre: Genre of content.
# -year: Release year of content.
# -age_rating: Age Rating for viewers
# -running_time: Running time of movie(in minutes).
# -season: Number of seasons of tv show.
# -episodes: Number of episodes of tv show.
# -type: Content is Tv show or Movie.

# %% [markdown]
# Data Exploration

# %%
ds.columns
# Out:
# Index(['hotstar_id', 'title', 'description', 'genre', 'year', 'age_rating',
#        'running_time', 'seasons', 'episodes', 'type'],
#       dtype='object')

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6874 entries, 0 to 6873
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   hotstar_id    6874 non-null   int64
#  1   title         6874 non-null   object
#  2   description   6874 non-null   object
#  3   genre         6874 non-null   object
#  4   year          6874 non-null   int64
#  5   age_rating    6874 non-null   object
#  6   running_time  4568 non-null   float64
#  7   seasons       2306 non-null   float64
#  8   episodes      2306 non-null   float64
#  9   type          6874 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 537.2+ KB

# %%
ds.isna().sum()
# Out:
# hotstar_id         0
# title              0
# description        0
# genre              0
# year               0
# age_rating         0
# running_time    2306
# seasons         4568
# episodes        4568
# type               0
# dtype: int64

# %%
ds.shape
# Out:
# (6874, 10)

# %%
ds.describe()
# Out:
#          hotstar_id         year  running_time      seasons     episodes
# count  6.874000e+03  6874.000000   4568.000000  2306.000000  2306.000000
# mean   1.059077e+09  2011.718650     98.746716     2.661752   127.366869
# std    4.812666e+08    11.936894     49.411142     4.942716   258.138186
# min    3.000000e+00  1928.000000      1.000000     1.000000     1.000000
# 25%    1.000088e+09  2009.000000     70.000000     1.000000     6.000000
# 50%    1.260008e+09  2016.000000    116.000000     1.000000    22.000000
# 75%    1.260099e+09  2019.000000    135.000000     2.000000   130.750000
# max    1.837059e+09  2023.000000    229.000000    73.000000  3973.000000

# %% [raw]
# While exploring data we have found that our dataset has 2306 missing values in running_time column,
# 4568 missing values in seasons and episodes column each.
# The dataset has 10 columns with 6874 count of rows.

# %%
import pandas_profiling 
pandas_profiling.ProfileReport(ds)
# Out:
#             <div>
#                 <ins><a href="ttps://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12884\989165297.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [raw]
# After reviewing the dataset through pandas profiling we observed that the hotstar id is unique,
# we have 16.6% of missing values out of dataset.
# In type the categories comprises of 4568 values of movies and
# 2306 of tv shows.
# The most contributing genre is drama with 2043 values,followed by comedy,romance,action and reality with 791,642,619 and 401 values respectively,
# While other values contributing 2378.
# Most of the movies were realsed in between 2000 and 2020 with 2018 serving as the year with most release.
# 5 Distinct age_rating category with U/A 13+ contributing with 2980 times in dataset.

# %% [markdown]
# Data Visualization

# %% [markdown]
# Is hotstar bias?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=ds, x='age_rating')
plt.title('Age Rating Distribution')
plt.xlabel('Age Rating')
plt.ylabel('Count')
plt.show()

# %% [raw]
# No hotstar is not a biased streaming platform.
# As we can see from the plot most of the categories can be stramed by 13+ rated individuals.

# %% [markdown]
# Why hotstar loves drama?

# %%
plt.figure(figsize=(12, 10))
sns.countplot(data=ds, y='genre', order=ds['genre'].value_counts().index)
plt.title('Genre Wise Distribution')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# Which category dominates hotstar platform?

# %%
type_ds=ds.groupby(['type','genre']).size().reset_index().rename(columns= {0:'count'})
comp=type_ds.pivot(index='genre',columns='type', values='count').plot(kind='bar',stacked=True)
plt.title('Comparison of Movie and TV Shows by Genre')
plt.ylabel('Number of Movie & TV')
plt.legend(['MOVIE','TV'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=ds, x='type')
plt.title('Category Distribution')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [raw]
# As we can clearly see from the plot that Movies category dominates the hotstar with 4568 no. of contributions

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=ds, x='year', bins=30)
plt.title('Release Year Distribution')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Data Pre-Processing

# %%
ds.isna().sum()
# Out:
# hotstar_id         0
# title              0
# description        0
# genre              0
# year               0
# age_rating         0
# running_time    2306
# seasons         4568
# episodes        4568
# type               0
# dtype: int64

# %%
ds['running_time'].fillna(ds['running_time'].mean(), inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12884\32511579.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ds['running_time'].fillna(ds['running_time'].mean(), inplace=True)

# %%
ds['seasons'].fillna(ds['seasons'].median(), inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12884\519194620.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ds['seasons'].fillna(ds['seasons'].median(), inplace=True)

# %%
ds['episodes'].fillna(ds['episodes'].mode()[0], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12884\1692952482.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ds['episodes'].fillna(ds['episodes'].mode()[0], inplace=True)

# %%
ds.isna().sum()
# Out:
# hotstar_id      0
# title           0
# description     0
# genre           0
# year            0
# age_rating      0
# running_time    0
# seasons         0
# episodes        0
# type            0
# dtype: int64

# %% [raw]
# The running_time is a numerical column, so we can use mean to fill missing values.
# We used median in the seasons column specifically because season counts can vary widely and may be influenced by outliers or missing data patterns.
# We used mode for the episodes column because it represents the most frequently occurring number of episodes in the dataset

# %%
ds.head()
# Out:
#    hotstar_id                                title  \
# 0  1000087439                Sambha - Aajcha Chawa
# 1  1260023113  Cars Toon: Mater And The Ghostlight
# 2  1260103188                Kanmani Rambo Khatija
# 3  1260126754                            Butterfly
# 4  1260018228                           Sister Act
#
#                                          description      genre  year  \
# 0  A young man sets off on a mission to clean up ...     Action  2012
# 1  Mater is haunted by a mysterious blue light th...  Animation  2006
# 2  Unlucky since birth, Rambo finds hope when he ...    Romance  2022
# 3  While trying to rescue her sister's kids from ...   Thriller  2022
# 4  Rene, a lounge singer, decides to stay at a Ch...     Comedy  1992
#
#   age_rating  running_time  seasons  episodes   type
# 0    U/A 16+         141.0      1.0       1.0  movie
# 1          U           7.0      1.0       1.0  movie
# 2    U/A 16+         157.0      1.0       1.0  movie
# ...

# %% [markdown]
# Feature Engineering

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
categorical_columns = ['genre', 'age_rating', 'type']
for col in categorical_columns:
    label_encoders[col] = LabelEncoder()
    ds[col] = label_encoders[col].fit_transform(ds[col])

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()
ds[['title', 'description']] = ordinal_encoder.fit_transform(ds[['title', 'description']])

# %% [raw]
# Ordinal Encoding – Assign a unique numeric value to each title and description, but this is mostly useful when working with a small, controlled set.
# Label Encoding - Will assign a unique numeric value to each category in the column.
# We did not used One Hot Encoding as it would have made the dataset too bulky.

# %% [markdown]
# Feature Selection

# %% [raw]
# Splitting the data into training and training set 70% and 30% respectively

# %%
from sklearn.model_selection import train_test_split
X = ds.drop('type', axis=1)
y = ds['type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42)

# %% [raw]
# Why KNN?
#
# K-Nearest Neighbors (KNN) is chosen for its simplicity and effectiveness, especially for small datasets.
# It’s non-parametric, meaning it doesn’t assume any specific data distribution.
# Since it requires no training phase, it’s easy to implement and works well for both classification and regression tasks.
# KNN is also great for non-linear data, making it versatile.
#
# Limitations:
# While powerful, KNN can be slow on large datasets due to its reliance on distance calculations.
# It’s also sensitive to irrelevant features, so proper scaling and feature selection are essential.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_mod = KNeighborsClassifier(n_neighbors=16)
knn_mod.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=16)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score
y_pred_knn = knn_mod.predict(X_test)
print(f"KNN Accuracy: {accuracy_score(y_test, y_pred_knn):.2f}")
# Out:
# KNN Accuracy: 0.86

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      1400
#            1       0.82      0.73      0.78       663
#
#     accuracy                           0.86      2063
#    macro avg       0.85      0.83      0.84      2063
# weighted avg       0.86      0.86      0.86      2063

# %% [raw]
# In this project we have used pandas and numpy for data handling and numerical computation.We have also used matplotlib and
# seaborn for data visualization.
# By working on the Hotstar data we have explored the content which is streamed on the platform.
# This project employs the K-Nearest Neighbors (KNN) algorithm to classify the target variable, "type"(which describes the content type),
# based on feature similarities.
# By leveraging KNN’s non-parametric nature and adaptability, the model successfully predicts categorical labels with 86% accuracy.
